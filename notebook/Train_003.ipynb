# %%
import pandas as pd

# %% [markdown]
# ## EDA: ドライバーごとのデータ数

# %%
df = pd.read_csv("../data/input/csvs/train.csv")
driver = pd.read_csv("../data/input/csvs/driver_imgs_list.csv")

# %%
#ドライバーの数
driver.subject.nunique()
# Out:
# 26

# %%
# ドライバーごとのデータ数
driver.groupby("subject").size()
# Out:
# subject
# p002     725
# p012     823
# p014     876
# p015     875
# p016    1078
# p021    1237
# p022    1233
# p024    1226
# p026    1196
# p035     848
# p039     651
# p041     605
# p042     591
# p045     724
# p047     835
# p049    1011
# p050     790
# p051     920
# p052     740
# p056     794
# p061     809
# p064     820
# p066    1034
# p072     346
# p075     814
# p081     823
# dtype: int64

# %% [markdown]
# ドライバーごとのデータ数と各ラベルの数を算出

# %%
def print_classname_size(driver_name):
    print(f"Driver name: {driver_name}\n")
#     print(driver[driver.subject==driver_name][""])
    driverrows = driver[driver.subject==driver_name]
    sumrows = len(driverrows)
    classnames = driver[driver.subject==driver_name]["classname"].unique()
    print(f"->Sum rows per a driver: {sumrows}")
#     print(driver[driver.subject==driver_name].groupby("classname").size())
    print()
    for classname in classnames:
        print(f"{classname} ratio: {round((len(driverrows[driverrows.classname==classname])/sumrows)*100,1)}%")

# %%
drivers = driver.subject.unique()
for d in drivers:
    print_classname_size(d)
# Out:
# Driver name: p002
#
# ->Sum rows per a driver: 725
#
# c0 ratio: 10.5%
# c1 ratio: 10.2%
# c2 ratio: 11.9%
# c3 ratio: 10.9%
# c4 ratio: 11.6%
# c5 ratio: 10.5%
# c6 ratio: 11.4%
# c7 ratio: 9.9%
# c8 ratio: 6.1%
# c9 ratio: 7.0%
# Driver name: p012
#
# ->Sum rows per a driver: 823
#
# c0 ratio: 10.2%
# c1 ratio: 11.5%
# c2 ratio: 11.1%
# c3 ratio: 10.8%
# c4 ratio: 11.8%
# c5 ratio: 11.7%
# c6 ratio: 9.1%
# c7 ratio: 8.7%
# c8 ratio: 7.5%
# c9 ratio: 7.5%
# Driver name: p014
#
# ->Sum rows per a driver: 876
#
# c0 ratio: 11.4%
# c1 ratio: 11.8%
# c2 ratio: 11.4%
# c3 ratio: 11.4%
# c4 ratio: 11.8%
# c5 ratio: 11.6%
# c6 ratio: 11.5%
# c7 ratio: 8.8%
# c8 ratio: 4.3%
# c9 ratio: 5.9%
# Driver name: p015
#
# ->Sum rows per a driver: 875
#
# c0 ratio: 9.0%
# c1 ratio: 9.7%
# c2 ratio: 10.1%
# c3 ratio: 10.7%
# c4 ratio: 11.5%
# c5 ratio: 11.5%
# c6 ratio: 11.3%
# c7 ratio: 9.3%
# c8 ratio: 9.8%
# c9 ratio: 7.0%
# Driver name: p016
#
# ->Sum rows per a driver: 1078
#
# c0 ratio: 10.3%
# c1 ratio: 9.5%
# c2 ratio: 9.4%
# c3 ratio: 11.9%
# c4 ratio: 9.6%
# c5 ratio: 9.6%
# c6 ratio: 10.0%
# c7 ratio: 9.4%
# c8 ratio: 9.2%
# c9 ratio: 11.1%
# Driver name: p021
#
# ->Sum rows per a driver: 1237
#
# c0 ratio: 10.9%
# c1 ratio: 10.6%
# c2 ratio: 10.3%
# c3 ratio: 10.3%
# c4 ratio: 10.7%
# c5 ratio: 10.5%
# c6 ratio: 10.2%
# c7 ratio: 7.9%
# c8 ratio: 8.0%
# c9 ratio: 10.6%
# Driver name: p022
#
# ->Sum rows per a driver: 1233
#
# c0 ratio: 10.5%
# c1 ratio: 10.5%
# c2 ratio: 10.4%
# c3 ratio: 10.5%
# c4 ratio: 10.5%
# c5 ratio: 10.5%
# c6 ratio: 10.6%
# c7 ratio: 7.9%
# c8 ratio: 7.9%
# c9 ratio: 10.6%
# Driver name: p024
#
# ->Sum rows per a driver: 1226
#
# c0 ratio: 10.6%
# c1 ratio: 10.5%
# c2 ratio: 10.4%
# c3 ratio: 10.6%
# c4 ratio: 10.5%
# c5 ratio: 10.7%
# c6 ratio: 10.5%
# c7 ratio: 8.2%
# c8 ratio: 8.1%
# c9 ratio: 9.8%
# Driver name: p026
#
# ->Sum rows per a driver: 1196
#
# c0 ratio: 10.9%
# c1 ratio: 10.8%
# c2 ratio: 10.9%
# c3 ratio: 11.0%
# c4 ratio: 10.5%
# c5 ratio: 10.9%
# c6 ratio: 10.7%
# c7 ratio: 8.1%
# c8 ratio: 8.1%
# c9 ratio: 8.2%
# Driver name: p035
#
# ->Sum rows per a driver: 848
#
# c0 ratio: 11.1%
# c1 ratio: 9.6%
# c2 ratio: 10.4%
# c3 ratio: 10.5%
# c4 ratio: 10.5%
# c5 ratio: 10.5%
# c6 ratio: 11.1%
# c7 ratio: 10.3%
# c8 ratio: 6.6%
# c9 ratio: 9.6%
# Driver name: p039
#
# ->Sum rows per a driver: 651
#
# c0 ratio: 10.0%
# c1 ratio: 9.7%
# c2 ratio: 10.8%
# c3 ratio: 10.0%
# c4 ratio: 9.5%
# c5 ratio: 9.8%
# c6 ratio: 9.7%
# c7 ratio: 9.8%
# c8 ratio: 10.8%
# c9 ratio: 10.0%
# Driver name: p041
#
# ->Sum rows per a driver: 605
#
# c0 ratio: 9.9%
# c1 ratio: 10.6%
# c2 ratio: 9.9%
# c3 ratio: 9.9%
# c4 ratio: 9.9%
# c5 ratio: 10.1%
# c6 ratio: 10.1%
# c7 ratio: 10.1%
# c8 ratio: 9.8%
# c9 ratio: 9.8%
# Driver name: p042
#
# ->Sum rows per a driver: 591
#
# c0 ratio: 10.0%
# c1 ratio: 10.0%
# c2 ratio: 10.2%
# c3 ratio: 10.0%
# c4 ratio: 9.8%
# c5 ratio: 10.0%
# c6 ratio: 10.0%
# c7 ratio: 10.0%
# c8 ratio: 10.0%
# c9 ratio: 10.2%
# Driver name: p045
#
# ->Sum rows per a driver: 724
#
# c0 ratio: 10.4%
# c1 ratio: 10.4%
# c2 ratio: 10.5%
# c3 ratio: 10.4%
# c4 ratio: 10.4%
# c5 ratio: 10.5%
# c6 ratio: 9.8%
# c7 ratio: 9.3%
# c8 ratio: 9.1%
# c9 ratio: 9.4%
# Driver name: p047
#
# ->Sum rows per a driver: 835
#
# c0 ratio: 9.6%
# c1 ratio: 10.9%
# c2 ratio: 9.7%
# c3 ratio: 10.3%
# c4 ratio: 9.8%
# c5 ratio: 10.4%
# c6 ratio: 9.7%
# c7 ratio: 9.8%
# c8 ratio: 9.8%
# c9 ratio: 9.9%
# Driver name: p049
#
# ->Sum rows per a driver: 1011
#
# c0 ratio: 8.3%
# c1 ratio: 8.4%
# c2 ratio: 11.8%
# c3 ratio: 10.9%
# c4 ratio: 10.8%
# c5 ratio: 11.5%
# c6 ratio: 11.8%
# c7 ratio: 7.3%
# c8 ratio: 7.8%
# c9 ratio: 11.5%
# Driver name: p050
#
# ->Sum rows per a driver: 790
#
# c0 ratio: 15.6%
# c1 ratio: 5.7%
# c2 ratio: 6.6%
# c3 ratio: 12.4%
# c4 ratio: 10.5%
# c5 ratio: 11.5%
# c6 ratio: 10.4%
# c7 ratio: 10.3%
# c8 ratio: 8.2%
# c9 ratio: 8.9%
# Driver name: p051
#
# ->Sum rows per a driver: 920
#
# c0 ratio: 19.8%
# c1 ratio: 8.8%
# c2 ratio: 8.8%
# c3 ratio: 9.0%
# c4 ratio: 8.8%
# c5 ratio: 9.0%
# c6 ratio: 10.3%
# c7 ratio: 8.7%
# c8 ratio: 6.7%
# c9 ratio: 10.0%
# Driver name: p052
#
# ->Sum rows per a driver: 740
#
# c0 ratio: 9.7%
# c1 ratio: 9.6%
# c2 ratio: 11.4%
# c3 ratio: 10.1%
# c4 ratio: 9.7%
# c5 ratio: 9.7%
# c6 ratio: 10.4%
# c7 ratio: 9.6%
# c8 ratio: 9.6%
# c9 ratio: 10.1%
# Driver name: p056
#
# ->Sum rows per a driver: 794
#
# c0 ratio: 10.2%
# c1 ratio: 10.1%
# c2 ratio: 10.1%
# c3 ratio: 9.8%
# c4 ratio: 10.3%
# c5 ratio: 10.2%
# c6 ratio: 10.1%
# c7 ratio: 9.3%
# c8 ratio: 10.5%
# c9 ratio: 9.4%
# Driver name: p061
#
# ->Sum rows per a driver: 809
#
# c0 ratio: 10.4%
# c1 ratio: 10.0%
# c2 ratio: 10.0%
# c3 ratio: 10.3%
# c4 ratio: 9.8%
# c5 ratio: 10.0%
# c6 ratio: 9.9%
# c7 ratio: 9.8%
# c8 ratio: 10.0%
# c9 ratio: 9.9%
# Driver name: p064
#
# ->Sum rows per a driver: 820
#
# c0 ratio: 10.1%
# c1 ratio: 9.9%
# c2 ratio: 10.1%
# c3 ratio: 10.2%
# c4 ratio: 10.5%
# c5 ratio: 10.4%
# c6 ratio: 10.0%
# c7 ratio: 9.6%
# c8 ratio: 9.9%
# c9 ratio: 9.3%
# Driver name: p066
#
# ->Sum rows per a driver: 1034
#
# c0 ratio: 12.5%
# c1 ratio: 9.7%
# c2 ratio: 10.3%
# c3 ratio: 9.8%
# c4 ratio: 9.9%
# c5 ratio: 9.8%
# c6 ratio: 10.2%
# c7 ratio: 8.3%
# c8 ratio: 11.0%
# c9 ratio: 8.7%
# Driver name: p072
#
# ->Sum rows per a driver: 346
#
# c0 ratio: 18.2%
# c1 ratio: 17.9%
# c2 ratio: 10.4%
# c3 ratio: 9.0%
# c4 ratio: 9.8%
# c5 ratio: 1.7%
# c6 ratio: 10.1%
# c7 ratio: 0.6%
# c8 ratio: 6.1%
# c9 ratio: 16.2%
# Driver name: p075
#
# ->Sum rows per a driver: 814
#
# c0 ratio: 10.0%
# c1 ratio: 10.0%
# c2 ratio: 10.4%
# c3 ratio: 9.7%
# c4 ratio: 10.9%
# c5 ratio: 9.7%
# c6 ratio: 10.1%
# c7 ratio: 10.1%
# c8 ratio: 9.7%
# c9 ratio: 9.5%
# Driver name: p081
#
# ->Sum rows per a driver: 823
#
# c0 ratio: 12.2%
# c1 ratio: 10.9%
# c2 ratio: 11.7%
# c3 ratio: 10.0%
# c4 ratio: 9.4%
# c5 ratio: 9.8%
# c6 ratio: 9.6%
# c7 ratio: 9.4%
# c8 ratio: 7.4%
# c9 ratio: 9.7%

# %% [markdown]
# ## ライブラリインストール

# %%
import os
import random

import numpy as np
import pandas as pd
# import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import KFold, StratifiedKFold, GroupKFold

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import plot_model, to_categorical, multi_gpu_model
from tensorflow.keras.layers import Input, Dense, Conv2D, Activation
from tensorflow.keras.layers import MaxPooling2D, UpSampling2D, BatchNormalization, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0

# %%
def set_randvalue(value):
    # Set a seed value
    seed_value= value 
    # 1. Set `PYTHONHASHSEED` environment variable at a fixed value
    os.environ['PYTHONHASHSEED']=str(seed_value)
    # 2. Set `python` built-in pseudo-random generator at a fixed value
    random.seed(seed_value)
    # 3. Set `numpy` pseudo-random generator at a fixed value
    np.random.seed(seed_value)
    # 4. Set `tensorflow` pseudo-random generator at a fixed value
    tf.random.set_seed(seed_value)

seed_value = 42
set_randvalue(seed_value)

# %% [markdown]
# ## CSVロード

# %%
# train.csvが元のラベルごとにディレクトリに保存されていたデータから作成したcsv
df = pd.read_csv("../data/input/csvs/train.csv")
df["label"] = df["label"].astype(str)
# df["img"] = df["image"]
df.head(3)
# Out:
#             image label
# 0  img_100026.jpg     0
# 1   img_10003.jpg     0
# 2  img_100050.jpg     0

# %%
driver["image"] = driver["img"]

# %%
# driver csvと元のcsvをマージ
merge_df = pd.merge(df, driver, on='image')
merge_df
# Out:
#                 image label subject classname             img
# 0      img_100026.jpg     0    p015        c0  img_100026.jpg
# 1       img_10003.jpg     0    p022        c0   img_10003.jpg
# 2      img_100050.jpg     0    p022        c0  img_100050.jpg
# 3      img_100074.jpg     0    p051        c0  img_100074.jpg
# 4       img_10012.jpg     0    p002        c0   img_10012.jpg
# ...               ...   ...     ...       ...             ...
# 22419   img_99761.jpg     9    p014        c9   img_99761.jpg
# 22420   img_99801.jpg     9    p050        c9   img_99801.jpg
# 22421   img_99927.jpg     9    p045        c9   img_99927.jpg
# 22422    img_9993.jpg     9    p042        c9    img_9993.jpg
# 22423   img_99949.jpg     9    p012        c9   img_99949.jpg
#
# [22424 rows x 5 columns]

# %% [markdown]
# ## モデル作成

# %%
# EfficientNetB0のモデルを作成
def create_model(weight_flg=False):
    weight = None
    if weight_flg:
        weight = "../model/efficientnetb0_notop.h5" # ImageNetで学習されたモデルをロード
    # include_top=False; 全結合層なし
    base_model = EfficientNetB0(weights=weight, include_top=False, pooling='avg', input_shape=(224,224,3))
    x = Dense(512, activation='relu')(base_model.output)
    x = Dropout(0.5)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(10, activation='softmax')(x)
    model = Model(base_model.input, output)
    
    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# EfficientNetB0のモデルを作成
def create_multigpu_model(weight_flg=False):
    tf.debugging.set_log_device_placement(True)

    strategy = tf.distribute.MirroredStrategy()
    with strategy.scope():
        weight = None
        if weight_flg:
            weight = "../model/efficientnetb0_notop.h5" # ImageNetで学習されたモデルをロード
        # include_top=False; 全結合層なし
        base_model = EfficientNetB0(weights=weight, include_top=False, pooling='avg', input_shape=(224,224,3))
        x = Dense(512, activation='relu')(base_model.output)
        x = Dropout(0.5)(x)
        x = Dense(512, activation='relu')(x)
        x = Dropout(0.5)(x)
        output = Dense(10, activation='softmax')(x)
        model = Model(base_model.input, output)

        model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
        return model

# %% [markdown]
# ## 学習

# %%
# Hyper parameters
img_size = 224
batch_size = 16
epochs = 250

# %%
# Generator作成
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20, # rotation range
    width_shift_range=30/img_size, # 30 pixel
    height_shift_range=30/img_size, # 30 pixel
    zoom_range=0.2
)

valid_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# %%time
# 学習と評価データでのラベルの分布数を一定に保ち学習
# skf = StratifiedKFold(n_splits = 5)
# splitter = skf.split(df["image"],df["label"])
gkf = GroupKFold(n_splits = 5)
splitter = gkf.split(merge_df["image"],merge_df["label"],merge_df["subject"])
for i, (train_ids, valid_ids) in enumerate(splitter, 1):
    # データ生成
    train, valid = df.iloc[train_ids], df.iloc[valid_ids]
    train_datagenerator = train_datagen.flow_from_dataframe(
        train,
        directory='../data/input/imgs/train/imgs/',
        x_col='image',
        y_col='label',
        target_size=(img_size, img_size),
        class_mode='categorical',
        batch_size=batch_size,
        seed=seed_value
    )

    valid_datagenerator = valid_datagen.flow_from_dataframe(
        valid,
        directory='../data/input/imgs/train/imgs/',
        x_col='image',
        y_col='label',
        target_size=(img_size, img_size),
        class_mode='categorical',
        batch_size=batch_size,
        seed=seed_value
    )
    
    model = create_model()
#     model = create_multigpu_model()
    
    # 早期終了
    early_stop = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')
    
    # 早期終了するのでval_lossが小さいモデルを保存
    model_path = '../model/' +  'Train003_' + "fold" + str(i) + "_best_model.h5"
    checkpoint = ModelCheckpoint(
                    filepath=model_path,
                    monitor='val_loss',
                    save_best_only=True,
                    period=1)
    
    history = model.fit(
        train_datagenerator,
        steps_per_epoch=int(len(train)//batch_size),
        epochs=epochs,
        validation_data=valid_datagenerator,
        validation_steps=int(len(valid)//batch_size),
        verbose=1,
        shuffle=True,
        callbacks=[early_stop, checkpoint])
# Out:
# Found 18017 validated image filenames belonging to 10 classes.
# Found 4407 validated image filenames belonging to 10 classes.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/250
# 1126/1126 [==============================] - 287s 255ms/step - loss: 2.3083 - accuracy: 0.1202 - val_loss: 3.7685 - val_accuracy: 0.1052
# Epoch 2/250
# 1126/1126 [==============================] - 182s 162ms/step - loss: 1.7633 - accuracy: 0.2930 - val_loss: 1.2895 - val_accuracy: 0.5020
# Epoch 3/250
# 1126/1126 [==============================] - 183s 162ms/step - loss: 1.1106 - accuracy: 0.5802 - val_loss: 0.9252 - val_accuracy: 0.7064
# Epoch 4/250
# 1126/1126 [==============================] - 182s 162ms/step - loss: 0.6654 - accuracy: 0.7736 - val_loss: 0.7839 - val_accuracy: 0.7580
# Epoch 5/250
# 1126/1126 [==============================] - 183s 162ms/step - loss: 0.4947 - accuracy: 0.8433 - val_loss: 0.7304 - val_accuracy: 0.7730
# Epoch 6/250
# 1126/1126 [==============================] - 182s 162ms/step - loss: 0.3945 - accuracy: 0.8857 - val_loss: 0.5963 - val_accuracy: 0.8393
# Epoch 7/250
# 1126/1126 [==============================] - 181s 161ms/step - loss: 0.3420 - accuracy: 0.9018 - val_loss: 0.8488 - val_accuracy: 0.8011
# Epoch 8/250
# 1126/1126 [==============================] - 186s 166ms/step - loss: 0.2921 - accuracy: 0.9202 - val_loss: 0.4672 - val_accuracy: 0.8743
# Epoch 9/250
# 1126/1126 [==============================] - 182s 161ms/step - loss: 0.2534 - accuracy: 0.9313 - val_loss: 0.6175 - val_accuracy: 0.8361
# Epoch 10/250
# 1126/1126 [==============================] - 182s 161ms/step - loss: 0.2165 - accuracy: 0.9418 - val_loss: 0.9103 - val_accuracy: 0.7889
# Epoch 11/250
# 1126/1126 [==============================] - 255s 227ms/step - loss: 0.2156 - accuracy: 0.9453 - val_loss: 0.6105 - val_accuracy: 0.8570
# Epoch 00011: early stopping
# Found 17949 validated image filenames belonging to 10 classes.
# Found 4475 validated image filenames belonging to 10 classes.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/250
# 1121/1121 [==============================] - 216s 192ms/step - loss: 2.3243 - accuracy: 0.1095 - val_loss: 2.3094 - val_accuracy: 0.1127
# Epoch 2/250
# 1121/1121 [==============================] - 181s 162ms/step - loss: 2.2784 - accuracy: 0.1370 - val_loss: 2.1544 - val_accuracy: 0.1942
# Epoch 3/250
# 1121/1121 [==============================] - 182s 162ms/step - loss: 1.9737 - accuracy: 0.2012 - val_loss: 1.7469 - val_accuracy: 0.1900
# Epoch 4/250
# 1121/1121 [==============================] - 182s 163ms/step - loss: 1.5965 - accuracy: 0.3438 - val_loss: 1.1937 - val_accuracy: 0.5175
# Epoch 11/250
# 1121/1121 [==============================] - 182s 162ms/step - loss: 0.1988 - accuracy: 0.9447 - val_loss: 0.9934 - val_accuracy: 0.7545
# Epoch 12/250
# 1121/1121 [==============================] - 182s 162ms/step - loss: 0.1909 - accuracy: 0.9505 - val_loss: 0.9792 - val_accuracy: 0.7659
# Epoch 13/250
# 1121/1121 [==============================] - 184s 164ms/step - loss: 0.1691 - accuracy: 0.9543 - val_loss: 0.8768 - val_accuracy: 0.7852
# Epoch 14/250
# 1121/1121 [==============================] - 183s 163ms/step - loss: 0.1626 - accuracy: 0.9541 - val_loss: 0.8286 - val_accuracy: 0.8479
# Epoch 15/250
# 1121/1121 [==============================] - 183s 163ms/step - loss: 0.1565 - accuracy: 0.9620 - val_loss: 1.1869 - val_accuracy: 0.7650
# Epoch 16/250
# 1121/1121 [==============================] - 183s 163ms/step - loss: 0.1382 - accuracy: 0.9629 - val_loss: 1.0306 - val_accuracy: 0.7603
# Epoch 17/250
# 1121/1121 [==============================] - 182s 163ms/step - loss: 0.1513 - accuracy: 0.9614 - val_loss: 0.6412 - val_accuracy: 0.8255
# Epoch 18/250
# 1121/1121 [==============================] - 183s 163ms/step - loss: 0.1323 - accuracy: 0.9660 - val_loss: 0.9772 - val_accuracy: 0.7953
# Epoch 19/250
# 1121/1121 [==============================] - 205s 183ms/step - loss: 0.1205 - accuracy: 0.9692 - val_loss: 1.5237 - val_accuracy: 0.7489
# Epoch 20/250
# 1121/1121 [==============================] - 248s 222ms/step - loss: 0.1170 - accuracy: 0.9704 - val_loss: 0.8445 - val_accuracy: 0.8051
# Epoch 00020: early stopping
# Wall time: 3h 8min 23s

# %% [markdown]
# ## 推論

# %%
submit = pd.read_csv('../data/input/csvs/sample_submission.csv')

test_generator = test_datagen.flow_from_dataframe(
    submit,
    directory='../data/input/imgs/test/',
    x_col='img',
    y_col='c0', # ダミー変数
    target_size=(img_size, img_size),
    class_mode=None,
    batch_size=1,
    verbose=1,
    shuffle=False
)

columns = submit.columns.values
labels = submit.columns[1:].values

def inference(fold_num):
    model = create_model()
    weight_path = '../model/Train003_fold' + str(fold_num) + '_best_model.h5'
    output_path = '../data/output/Train003_fold' + str(fold_num) + '_sub.csv'
    model.load_weights(weight_path)
    
    pred = model.predict(test_generator, verbose=1)
    pred_df = pd.DataFrame(columns=columns)
    pred_df['img'] = submit['img']
    pred_df[labels] = pred
    pred_df.to_csv(output_path, index=False)
    
for i in range(1,6):
    inference(i)
# Out:
# Found 79726 validated image filenames.
# 79726/79726 [==============================] - 599s 8ms/step
# 79726/79726 [==============================] - 464s 6ms/step
#     1/79726 [..............................] - ETA: 0sWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_predict_batch_end` time: 0.0156s). Check your callbacks.
# 79726/79726 [==============================] - 465s 6ms/step
# 79726/79726 [==============================] - 461s 6ms/step
# 79726/79726 [==============================] - 540s 7ms/step

# %% [markdown]
# ## アンサンブル：単純平均
